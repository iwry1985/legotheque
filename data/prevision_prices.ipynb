# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, text

from pycaret.regression import *
from pycaret.time_series import TSForecastingExperiment

# %%
##CONFIG DB
WAREHOUSE = "postgresql://postgres:technofutur2025@localhost:5432/legothec_warehouse"
engine = create_engine(WAREHOUSE)

query = text("""
             SELECT * FROM d_legoset
             """)

with engine.connect() as con:
    f_sales = pd.read_sql_table(table_name="f_sales", con=con)
    d_legoset = pd.read_sql(query, con=con)
    
data = d_legoset[["minifigs", "retail_price", "pieces", "launch_year", "theme_group"]].copy()

data.isna().sum()

data.dropna(inplace=True)

data.shape
# Out:
# (5471, 5)

# %%
df = data.copy()
df = df[df["pieces"] > 0].reset_index(drop=True)

# cible plus stable
df["price_per_piece"] = df["retail_price"] / df["pieces"]

# catégories de taille
df["size_category"] = pd.cut(
    df["pieces"],
    bins=[0, 500, 1000, 2000, 3000, df["pieces"].max()],
    labels=["<500", "500-1000", "1000-2000", "2000-3000", "3000+"],
    include_lowest=True
)

# %%
models_by_group = {}
ppp_bounds_by_group = {}  # pour couper les délires (clips)

group_col = "theme_group"   # change en "theme" si tu préfères par thème fin
min_rows = 80               # seuil mini pour entraîner un modèle par groupe

for g, gdf in df.groupby(group_col):
    if len(gdf) < min_rows:
        continue  # pas assez de données, on sautera ce groupe

    reg_setup = setup(
        data=gdf,
        target="price_per_piece",
        session_id=42,
        categorical_features=["size_category"],
        numeric_features=["pieces", "minifigs", "launch_year"],
        verbose=False,
    )
    mdl = compare_models()                 # ExtraTrees/RandomForest sortent souvent en tête
    models_by_group[g] = finalize_model(mdl)

    # bornes robustes (pour éviter les PPP délirants à la prédiction)
    low = gdf["price_per_piece"].quantile(0.02)
    high = gdf["price_per_piece"].quantile(0.98)
    ppp_bounds_by_group[g] = (float(low), float(high))

# Un modèle global (fallback si pas assez de données dans un groupe)
reg_setup_global = setup(
    data=df,
    target="price_per_piece",
    session_id=43,
    categorical_features=["theme_group", "size_category"],
    numeric_features=["pieces", "minifigs", "launch_year"],
    verbose=False,
)
global_model = finalize_model(compare_models())
global_bounds = (float(df["price_per_piece"].quantile(0.02)),
                 float(df["price_per_piece"].quantile(0.98)))
# Out:
# <style type="text/css">
# #T_0bb87 th {
#   text-align: left;
# }
# #T_0bb87_row0_col0, #T_0bb87_row1_col0, #T_0bb87_row1_col1, #T_0bb87_row1_col2, #T_0bb87_row1_col3, #T_0bb87_row1_col4, #T_0bb87_row1_col5, #T_0bb87_row1_col6 {
#   text-align: left;
# }
# #T_0bb87_row0_col1, #T_0bb87_row0_col2, #T_0bb87_row0_col3, #T_0bb87_row0_col4, #T_0bb87_row0_col5, #T_0bb87_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0bb87_row0_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0bb87_row1_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0bb87">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0bb87_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0bb87_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_0bb87_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_0bb87_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_0bb87_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_0bb87_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_0bb87_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_0bb87_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0bb87_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_0bb87_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0bb87_row0_col1" class="data row0 col1" >0.0136</td>
#       <td id="T_0bb87_row0_col2" class="data row0 col2" >0.0007</td>
#       <td id="T_0bb87_row0_col3" class="data row0 col3" >0.0224</td>
#       <td id="T_0bb87_row0_col4" class="data row0 col4" >0.5144</td>
#       <td id="T_0bb87_row0_col5" class="data row0 col5" >0.0194</td>
#       <td id="T_0bb87_row0_col6" class="data row0 col6" >0.1386</td>
#       <td id="T_0bb87_row0_col7" class="data row0 col7" >0.0530</td>
#     </tr>
#     <tr>
#       <th id="T_0bb87_level0_row1" class="row_heading level0 row1" >dummy</th>
#       <td id="T_0bb87_row1_col0" class="data row1 col0" >Dummy Regressor</td>
#       <td id="T_0bb87_row1_col1" class="data row1 col1" >0.0229</td>
#       <td id="T_0bb87_row1_col2" class="data row1 col2" >0.0013</td>
#       <td id="T_0bb87_row1_col3" class="data row1 col3" >0.0333</td>
#       <td id="T_0bb87_row1_col4" class="data row1 col4" >-0.0808</td>
#       <td id="T_0bb87_row1_col5" class="data row1 col5" >0.0296</td>
#       <td id="T_0bb87_row1_col6" class="data row1 col6" >0.2818</td>
#       <td id="T_0bb87_row1_col7" class="data row1 col7" >0.0210</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ca660 th {
#   text-align: left;
# }
# #T_ca660_row0_col0, #T_ca660_row0_col1, #T_ca660_row0_col2, #T_ca660_row0_col3, #T_ca660_row0_col5, #T_ca660_row0_col6, #T_ca660_row1_col0, #T_ca660_row1_col4 {
#   text-align: left;
# }
# #T_ca660_row0_col4, #T_ca660_row1_col1, #T_ca660_row1_col2, #T_ca660_row1_col3, #T_ca660_row1_col5, #T_ca660_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ca660_row0_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_ca660_row1_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ca660">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca660_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ca660_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ca660_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ca660_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ca660_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ca660_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ca660_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ca660_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca660_level0_row0" class="row_heading level0 row0" >dummy</th>
#       <td id="T_ca660_row0_col0" class="data row0 col0" >Dummy Regressor</td>
#       <td id="T_ca660_row0_col1" class="data row0 col1" >1.8745</td>
#       <td id="T_ca660_row0_col2" class="data row0 col2" >75.8355</td>
#       <td id="T_ca660_row0_col3" class="data row0 col3" >5.1973</td>
#       <td id="T_ca660_row0_col4" class="data row0 col4" >-84.1754</td>
#       <td id="T_ca660_row0_col5" class="data row0 col5" >0.7466</td>
#       <td id="T_ca660_row0_col6" class="data row0 col6" >8.9659</td>
#       <td id="T_ca660_row0_col7" class="data row0 col7" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_ca660_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_ca660_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ca660_row1_col1" class="data row1 col1" >1.6889</td>
#       <td id="T_ca660_row1_col2" class="data row1 col2" >54.9141</td>
#       <td id="T_ca660_row1_col3" class="data row1 col3" >4.6259</td>
#       <td id="T_ca660_row1_col4" class="data row1 col4" >-195.6483</td>
#       <td id="T_ca660_row1_col5" class="data row1 col5" >0.6578</td>
#       <td id="T_ca660_row1_col6" class="data row1 col6" >7.3209</td>
#       <td id="T_ca660_row1_col7" class="data row1 col7" >0.0640</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8e21c th {
#   text-align: left;
# }
# #T_8e21c_row0_col0, #T_8e21c_row0_col1, #T_8e21c_row0_col2, #T_8e21c_row0_col3, #T_8e21c_row0_col5, #T_8e21c_row0_col6, #T_8e21c_row1_col0, #T_8e21c_row1_col4 {
#   text-align: left;
# }
# #T_8e21c_row0_col4, #T_8e21c_row1_col1, #T_8e21c_row1_col2, #T_8e21c_row1_col3, #T_8e21c_row1_col5, #T_8e21c_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_8e21c_row0_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_8e21c_row1_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_8e21c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e21c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8e21c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_8e21c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_8e21c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_8e21c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_8e21c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_8e21c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_8e21c_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e21c_level0_row0" class="row_heading level0 row0" >dummy</th>
#       <td id="T_8e21c_row0_col0" class="data row0 col0" >Dummy Regressor</td>
#       <td id="T_8e21c_row0_col1" class="data row0 col1" >0.1270</td>
#       <td id="T_8e21c_row0_col2" class="data row0 col2" >0.4985</td>
#       <td id="T_8e21c_row0_col3" class="data row0 col3" >0.4976</td>
#       <td id="T_8e21c_row0_col4" class="data row0 col4" >-0.5546</td>
#       <td id="T_8e21c_row0_col5" class="data row0 col5" >0.1597</td>
#       <td id="T_8e21c_row0_col6" class="data row0 col6" >0.8019</td>
#       <td id="T_8e21c_row0_col7" class="data row0 col7" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_8e21c_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_8e21c_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_8e21c_row1_col1" class="data row1 col1" >0.0885</td>
#       <td id="T_8e21c_row1_col2" class="data row1 col2" >0.2833</td>
#       <td id="T_8e21c_row1_col3" class="data row1 col3" >0.4402</td>
#       <td id="T_8e21c_row1_col4" class="data row1 col4" >-3.5077</td>
#       <td id="T_8e21c_row1_col5" class="data row1 col5" >0.1143</td>
#       <td id="T_8e21c_row1_col6" class="data row1 col6" >0.3538</td>
#       <td id="T_8e21c_row1_col7" class="data row1 col7" >0.0920</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_388a3 th {
#   text-align: left;
# }
# #T_388a3_row0_col0, #T_388a3_row1_col0, #T_388a3_row1_col1, #T_388a3_row1_col2, #T_388a3_row1_col3, #T_388a3_row1_col4, #T_388a3_row1_col5, #T_388a3_row1_col6 {
#   text-align: left;
# }
# #T_388a3_row0_col1, #T_388a3_row0_col2, #T_388a3_row0_col3, #T_388a3_row0_col4, #T_388a3_row0_col5, #T_388a3_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_388a3_row0_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_388a3_row1_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_388a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_388a3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_388a3_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_388a3_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_388a3_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_388a3_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_388a3_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_388a3_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_388a3_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_388a3_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_388a3_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_388a3_row0_col1" class="data row0 col1" >0.0756</td>
#       <td id="T_388a3_row0_col2" class="data row0 col2" >0.0881</td>
#       <td id="T_388a3_row0_col3" class="data row0 col3" >0.2095</td>
#       <td id="T_388a3_row0_col4" class="data row0 col4" >0.8348</td>
#       <td id="T_388a3_row0_col5" class="data row0 col5" >0.0791</td>
#       <td id="T_388a3_row0_col6" class="data row0 col6" >0.1701</td>
#       <td id="T_388a3_row0_col7" class="data row0 col7" >0.0790</td>
#     </tr>
#     <tr>
#       <th id="T_388a3_level0_row1" class="row_heading level0 row1" >dummy</th>
#       <td id="T_388a3_row1_col0" class="data row1 col0" >Dummy Regressor</td>
#       <td id="T_388a3_row1_col1" class="data row1 col1" >0.3833</td>
#       <td id="T_388a3_row1_col2" class="data row1 col2" >0.2805</td>
#       <td id="T_388a3_row1_col3" class="data row1 col3" >0.4974</td>
#       <td id="T_388a3_row1_col4" class="data row1 col4" >-0.0305</td>
#       <td id="T_388a3_row1_col5" class="data row1 col5" >0.2849</td>
#       <td id="T_388a3_row1_col6" class="data row1 col6" >2.0851</td>
#       <td id="T_388a3_row1_col7" class="data row1 col7" >0.0180</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b4a72 th {
#   text-align: left;
# }
# #T_b4a72_row0_col0, #T_b4a72_row1_col0, #T_b4a72_row1_col1, #T_b4a72_row1_col2, #T_b4a72_row1_col3, #T_b4a72_row1_col4, #T_b4a72_row1_col5, #T_b4a72_row1_col6 {
#   text-align: left;
# }
# #T_b4a72_row0_col1, #T_b4a72_row0_col2, #T_b4a72_row0_col3, #T_b4a72_row0_col4, #T_b4a72_row0_col5, #T_b4a72_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_b4a72_row0_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_b4a72_row1_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_b4a72">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4a72_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b4a72_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_b4a72_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_b4a72_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_b4a72_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_b4a72_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_b4a72_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_b4a72_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4a72_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_b4a72_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_b4a72_row0_col1" class="data row0 col1" >0.0200</td>
#       <td id="T_b4a72_row0_col2" class="data row0 col2" >0.0022</td>
#       <td id="T_b4a72_row0_col3" class="data row0 col3" >0.0394</td>
#       <td id="T_b4a72_row0_col4" class="data row0 col4" >0.3513</td>
#       <td id="T_b4a72_row0_col5" class="data row0 col5" >0.0294</td>
#       <td id="T_b4a72_row0_col6" class="data row0 col6" >0.1518</td>
#       <td id="T_b4a72_row0_col7" class="data row0 col7" >0.0610</td>
#     </tr>
#     <tr>
#       <th id="T_b4a72_level0_row1" class="row_heading level0 row1" >dummy</th>
#       <td id="T_b4a72_row1_col0" class="data row1 col0" >Dummy Regressor</td>
#       <td id="T_b4a72_row1_col1" class="data row1 col1" >0.0388</td>
#       <td id="T_b4a72_row1_col2" class="data row1 col2" >0.0104</td>
#       <td id="T_b4a72_row1_col3" class="data row1 col3" >0.0834</td>
#       <td id="T_b4a72_row1_col4" class="data row1 col4" >-0.4387</td>
#       <td id="T_b4a72_row1_col5" class="data row1 col5" >0.0616</td>
#       <td id="T_b4a72_row1_col6" class="data row1 col6" >0.2714</td>
#       <td id="T_b4a72_row1_col7" class="data row1 col7" >0.0160</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2003f th {
#   text-align: left;
# }
# #T_2003f_row0_col0, #T_2003f_row1_col0, #T_2003f_row1_col1, #T_2003f_row1_col2, #T_2003f_row1_col3, #T_2003f_row1_col4, #T_2003f_row1_col5, #T_2003f_row1_col6 {
#   text-align: left;
# }
# #T_2003f_row0_col1, #T_2003f_row0_col2, #T_2003f_row0_col3, #T_2003f_row0_col4, #T_2003f_row0_col5, #T_2003f_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_2003f_row0_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_2003f_row1_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_2003f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2003f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2003f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_2003f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_2003f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_2003f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_2003f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_2003f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_2003f_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2003f_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_2003f_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_2003f_row0_col1" class="data row0 col1" >0.0067</td>
#       <td id="T_2003f_row0_col2" class="data row0 col2" >0.0006</td>
#       <td id="T_2003f_row0_col3" class="data row0 col3" >0.0206</td>
#       <td id="T_2003f_row0_col4" class="data row0 col4" >0.8825</td>
#       <td id="T_2003f_row0_col5" class="data row0 col5" >0.0151</td>
#       <td id="T_2003f_row0_col6" class="data row0 col6" >0.0425</td>
#       <td id="T_2003f_row0_col7" class="data row0 col7" >0.0930</td>
#     </tr>
#     <tr>
#       <th id="T_2003f_level0_row1" class="row_heading level0 row1" >dummy</th>
#       <td id="T_2003f_row1_col0" class="data row1 col0" >Dummy Regressor</td>
#       <td id="T_2003f_row1_col1" class="data row1 col1" >0.0400</td>
#       <td id="T_2003f_row1_col2" class="data row1 col2" >0.0041</td>
#       <td id="T_2003f_row1_col3" class="data row1 col3" >0.0626</td>
#       <td id="T_2003f_row1_col4" class="data row1 col4" >-0.0069</td>
#       <td id="T_2003f_row1_col5" class="data row1 col5" >0.0516</td>
#       <td id="T_2003f_row1_col6" class="data row1 col6" >0.3159</td>
#       <td id="T_2003f_row1_col7" class="data row1 col7" >0.0290</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e8805 th {
#   text-align: left;
# }
# #T_e8805_row0_col0, #T_e8805_row1_col0, #T_e8805_row1_col1, #T_e8805_row1_col2, #T_e8805_row1_col3, #T_e8805_row1_col4, #T_e8805_row1_col5, #T_e8805_row1_col6 {
#   text-align: left;
# }
# #T_e8805_row0_col1, #T_e8805_row0_col2, #T_e8805_row0_col3, #T_e8805_row0_col4, #T_e8805_row0_col5, #T_e8805_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_e8805_row0_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_e8805_row1_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_e8805">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8805_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e8805_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e8805_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e8805_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e8805_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e8805_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e8805_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_e8805_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8805_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_e8805_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_e8805_row0_col1" class="data row0 col1" >0.0717</td>
#       <td id="T_e8805_row0_col2" class="data row0 col2" >0.0187</td>
#       <td id="T_e8805_row0_col3" class="data row0 col3" >0.1158</td>
#       <td id="T_e8805_row0_col4" class="data row0 col4" >-0.6386</td>
#       <td id="T_e8805_row0_col5" class="data row0 col5" >0.0869</td>
#       <td id="T_e8805_row0_col6" class="data row0 col6" >0.5190</td>
#       <td id="T_e8805_row0_col7" class="data row0 col7" >0.0420</td>
#     </tr>
#     <tr>
#       <th id="T_e8805_level0_row1" class="row_heading level0 row1" >dummy</th>
#       <td id="T_e8805_row1_col0" class="data row1 col0" >Dummy Regressor</td>
#       <td id="T_e8805_row1_col1" class="data row1 col1" >0.1000</td>
#       <td id="T_e8805_row1_col2" class="data row1 col2" >0.0259</td>
#       <td id="T_e8805_row1_col3" class="data row1 col3" >0.1352</td>
#       <td id="T_e8805_row1_col4" class="data row1 col4" >-5.4510</td>
#       <td id="T_e8805_row1_col5" class="data row1 col5" >0.1041</td>
#       <td id="T_e8805_row1_col6" class="data row1 col6" >0.7417</td>
#       <td id="T_e8805_row1_col7" class="data row1 col7" >0.0160</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_11091 th {
#   text-align: left;
# }
# #T_11091_row0_col0, #T_11091_row1_col0, #T_11091_row1_col1, #T_11091_row1_col2, #T_11091_row1_col3, #T_11091_row1_col4, #T_11091_row1_col5, #T_11091_row1_col6 {
#   text-align: left;
# }
# #T_11091_row0_col1, #T_11091_row0_col2, #T_11091_row0_col3, #T_11091_row0_col4, #T_11091_row0_col5, #T_11091_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_11091_row0_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_11091_row1_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_11091">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11091_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_11091_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_11091_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_11091_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_11091_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_11091_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_11091_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_11091_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11091_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_11091_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_11091_row0_col1" class="data row0 col1" >0.0095</td>
#       <td id="T_11091_row0_col2" class="data row0 col2" >0.0002</td>
#       <td id="T_11091_row0_col3" class="data row0 col3" >0.0120</td>
#       <td id="T_11091_row0_col4" class="data row0 col4" >0.0760</td>
#       <td id="T_11091_row0_col5" class="data row0 col5" >0.0110</td>
#       <td id="T_11091_row0_col6" class="data row0 col6" >0.1174</td>
#       <td id="T_11091_row0_col7" class="data row0 col7" >0.0370</td>
#     </tr>
#     <tr>
#       <th id="T_11091_level0_row1" class="row_heading level0 row1" >dummy</th>
#       <td id="T_11091_row1_col0" class="data row1 col0" >Dummy Regressor</td>
#       <td id="T_11091_row1_col1" class="data row1 col1" >0.0135</td>
#       <td id="T_11091_row1_col2" class="data row1 col2" >0.0003</td>
#       <td id="T_11091_row1_col3" class="data row1 col3" >0.0157</td>
#       <td id="T_11091_row1_col4" class="data row1 col4" >-0.5163</td>
#       <td id="T_11091_row1_col5" class="data row1 col5" >0.0144</td>
#       <td id="T_11091_row1_col6" class="data row1 col6" >0.1663</td>
#       <td id="T_11091_row1_col7" class="data row1 col7" >0.0160</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_bf6f8 th {
#   text-align: left;
# }
# #T_bf6f8_row0_col0, #T_bf6f8_row0_col1, #T_bf6f8_row0_col2, #T_bf6f8_row0_col3, #T_bf6f8_row1_col0, #T_bf6f8_row1_col1, #T_bf6f8_row1_col2, #T_bf6f8_row1_col3, #T_bf6f8_row1_col4, #T_bf6f8_row1_col5, #T_bf6f8_row1_col6, #T_bf6f8_row2_col0, #T_bf6f8_row2_col1, #T_bf6f8_row2_col2, #T_bf6f8_row2_col3, #T_bf6f8_row2_col4, #T_bf6f8_row2_col5, #T_bf6f8_row2_col6, #T_bf6f8_row3_col0, #T_bf6f8_row3_col1, #T_bf6f8_row3_col2, #T_bf6f8_row3_col3, #T_bf6f8_row3_col4, #T_bf6f8_row3_col5, #T_bf6f8_row3_col6, #T_bf6f8_row4_col0, #T_bf6f8_row4_col4, #T_bf6f8_row4_col5, #T_bf6f8_row4_col6, #T_bf6f8_row5_col0, #T_bf6f8_row5_col1, #T_bf6f8_row5_col2, #T_bf6f8_row5_col3, #T_bf6f8_row5_col4, #T_bf6f8_row5_col5, #T_bf6f8_row5_col6, #T_bf6f8_row6_col0, #T_bf6f8_row6_col1, #T_bf6f8_row6_col2, #T_bf6f8_row6_col3, #T_bf6f8_row6_col4, #T_bf6f8_row6_col5, #T_bf6f8_row6_col6, #T_bf6f8_row7_col0, #T_bf6f8_row7_col1, #T_bf6f8_row7_col2, #T_bf6f8_row7_col3, #T_bf6f8_row7_col4, #T_bf6f8_row7_col5, #T_bf6f8_row7_col6, #T_bf6f8_row8_col0, #T_bf6f8_row8_col1, #T_bf6f8_row8_col2, #T_bf6f8_row8_col3, #T_bf6f8_row8_col4, #T_bf6f8_row8_col5, #T_bf6f8_row8_col6, #T_bf6f8_row9_col0, #T_bf6f8_row9_col1, #T_bf6f8_row9_col2, #T_bf6f8_row9_col3, #T_bf6f8_row9_col4, #T_bf6f8_row9_col5, #T_bf6f8_row9_col6, #T_bf6f8_row10_col0, #T_bf6f8_row10_col1, #T_bf6f8_row10_col2, #T_bf6f8_row10_col3, #T_bf6f8_row10_col4, #T_bf6f8_row10_col5, #T_bf6f8_row10_col6, #T_bf6f8_row11_col0, #T_bf6f8_row11_col1, #T_bf6f8_row11_col2, #T_bf6f8_row11_col3, #T_bf6f8_row11_col4, #T_bf6f8_row11_col5, #T_bf6f8_row11_col6, #T_bf6f8_row12_col0, #T_bf6f8_row12_col1, #T_bf6f8_row12_col2, #T_bf6f8_row12_col3, #T_bf6f8_row12_col4, #T_bf6f8_row12_col5, #T_bf6f8_row12_col6, #T_bf6f8_row13_col0, #T_bf6f8_row13_col1, #T_bf6f8_row13_col2, #T_bf6f8_row13_col3, #T_bf6f8_row13_col4, #T_bf6f8_row13_col5, #T_bf6f8_row13_col6, #T_bf6f8_row14_col0, #T_bf6f8_row14_col1, #T_bf6f8_row14_col2, #T_bf6f8_row14_col3, #T_bf6f8_row14_col4, #T_bf6f8_row14_col5, #T_bf6f8_row14_col6, #T_bf6f8_row15_col0, #T_bf6f8_row15_col1, #T_bf6f8_row15_col2, #T_bf6f8_row15_col3, #T_bf6f8_row15_col4, #T_bf6f8_row15_col5, #T_bf6f8_row15_col6, #T_bf6f8_row16_col0, #T_bf6f8_row16_col1, #T_bf6f8_row16_col2, #T_bf6f8_row16_col3, #T_bf6f8_row16_col4, #T_bf6f8_row16_col5, #T_bf6f8_row16_col6, #T_bf6f8_row17_col0, #T_bf6f8_row17_col1, #T_bf6f8_row17_col2, #T_bf6f8_row17_col3, #T_bf6f8_row17_col4, #T_bf6f8_row17_col5, #T_bf6f8_row17_col6 {
#   text-align: left;
# }
# #T_bf6f8_row0_col4, #T_bf6f8_row0_col5, #T_bf6f8_row0_col6, #T_bf6f8_row4_col1, #T_bf6f8_row4_col2, #T_bf6f8_row4_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_bf6f8_row0_col7, #T_bf6f8_row1_col7, #T_bf6f8_row2_col7, #T_bf6f8_row3_col7, #T_bf6f8_row4_col7, #T_bf6f8_row5_col7, #T_bf6f8_row7_col7, #T_bf6f8_row8_col7, #T_bf6f8_row9_col7, #T_bf6f8_row10_col7, #T_bf6f8_row11_col7, #T_bf6f8_row12_col7, #T_bf6f8_row13_col7, #T_bf6f8_row14_col7, #T_bf6f8_row15_col7, #T_bf6f8_row16_col7, #T_bf6f8_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_bf6f8_row6_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_bf6f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf6f8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bf6f8_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_bf6f8_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_bf6f8_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_bf6f8_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_bf6f8_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_bf6f8_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_bf6f8_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf6f8_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_bf6f8_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_bf6f8_row0_col1" class="data row0 col1" >0.0581</td>
#       <td id="T_bf6f8_row0_col2" class="data row0 col2" >3.6396</td>
#       <td id="T_bf6f8_row0_col3" class="data row0 col3" >0.8781</td>
#       <td id="T_bf6f8_row0_col4" class="data row0 col4" >0.7304</td>
#       <td id="T_bf6f8_row0_col5" class="data row0 col5" >0.0376</td>
#       <td id="T_bf6f8_row0_col6" class="data row0 col6" >0.0293</td>
#       <td id="T_bf6f8_row0_col7" class="data row0 col7" >0.2920</td>
#     </tr>
#     <tr>
#       <th id="T_bf6f8_level0_row1" class="row_heading level0 row1" >knn</th>
#       <td id="T_bf6f8_row1_col0" class="data row1 col0" >K Neighbors Regressor</td>
#       <td id="T_bf6f8_row1_col1" class="data row1 col1" >0.0668</td>
#       <td id="T_bf6f8_row1_col2" class="data row1 col2" >4.2766</td>
#       <td id="T_bf6f8_row1_col3" class="data row1 col3" >0.9396</td>
#       <td id="T_bf6f8_row1_col4" class="data row1 col4" >0.7134</td>
#       <td id="T_bf6f8_row1_col5" class="data row1 col5" >0.0521</td>
#       <td id="T_bf6f8_row1_col6" class="data row1 col6" >0.0607</td>
#       <td id="T_bf6f8_row1_col7" class="data row1 col7" >0.0350</td>
#     </tr>
#     <tr>
#       <th id="T_bf6f8_level0_row2" class="row_heading level0 row2" >gbr</th>
#       <td id="T_bf6f8_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_bf6f8_row2_col1" class="data row2 col1" >0.0731</td>
#       <td id="T_bf6f8_row2_col2" class="data row2 col2" >4.3737</td>
#       <td id="T_bf6f8_row2_col3" class="data row2 col3" >0.9592</td>
#       <td id="T_bf6f8_row2_col4" class="data row2 col4" >0.5992</td>
#       <td id="T_bf6f8_row2_col5" class="data row2 col5" >0.0479</td>
#       <td id="T_bf6f8_row2_col6" class="data row2 col6" >0.1384</td>
#       <td id="T_bf6f8_row2_col7" class="data row2 col7" >0.1030</td>
#     </tr>
#     <tr>
#       <th id="T_bf6f8_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_bf6f8_row3_col0" class="data row3 col0" >AdaBoost Regressor</td>
#       <td id="T_bf6f8_row3_col1" class="data row3 col1" >0.1618</td>
#       <td id="T_bf6f8_row3_col2" class="data row3 col2" >2.7944</td>
#       <td id="T_bf6f8_row3_col3" class="data row3 col3" >0.8939</td>
#       <td id="T_bf6f8_row3_col4" class="data row3 col4" >0.5674</td>
#       <td id="T_bf6f8_row3_col5" class="data row3 col5" >0.1245</td>
#       <td id="T_bf6f8_row3_col6" class="data row3 col6" >0.9547</td>
#       <td id="T_bf6f8_row3_col7" class="data row3 col7" >0.0430</td>
#     </tr>
#     <tr>
#       <th id="T_bf6f8_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_bf6f8_row4_col0" class="data row4 col0" >Extra Trees Regressor</td>
#       <td id="T_bf6f8_row4_col1" class="data row4 col1" >0.0570</td>
#       <td id="T_bf6f8_row4_col2" class="data row4 col2" >2.6046</td>
#       <td id="T_bf6f8_row4_col3" class="data row4 col3" >0.7965</td>
#       <td id="T_bf6f8_row4_col4" class="data row4 col4" >0.5369</td>
#       <td id="T_bf6f8_row4_col5" class="data row4 col5" >0.0680</td>
#       <td id="T_bf6f8_row4_col6" class="data row4 col6" >0.0726</td>
#       <td id="T_bf6f8_row4_col7" class="data row4 col7" >0.1930</td>
#     </tr>
#     <tr>
#       <th id="T_bf6f8_level0_row5" class="row_heading level0 row5" >huber</th>
#       <td id="T_bf6f8_row5_col0" class="data row5 col0" >Huber Regressor</td>
#       <td id="T_bf6f8_row5_col1" class="data row5 col1" >0.1510</td>
#       <td id="T_bf6f8_row5_col2" class="data row5 col2" >5.3968</td>
#       <td id="T_bf6f8_row5_col3" class="data row5 col3" >1.3774</td>
#       <td id="T_bf6f8_row5_col4" class="data row5 col4" >0.0149</td>
#       <td id="T_bf6f8_row5_col5" class="data row5 col5" >0.1894</td>
#       <td id="T_bf6f8_row5_col6" class="data row5 col6" >0.2949</td>
#       <td id="T_bf6f8_row5_col7" class="data row5 col7" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_bf6f8_level0_row6" class="row_head

# %%
def build_time_factor_by_group(fh=10):
    factors = {}
    # global
    dfg = (df.groupby("launch_year")["price_per_piece"].mean()
             .reset_index().rename(columns={"launch_year":"date","price_per_piece":"y"}))
    dfg["date"] = pd.to_datetime(dfg["date"], format="%Y")

    expg = TSForecastingExperiment()
    expg.setup(data=dfg, target="y", session_id=7, fh=fh, fold=2, numeric_imputation_target="linear")
    bestg = expg.compare_models(turbo=True)
    predg = expg.predict_model(bestg, fh=fh)
    factors["_GLOBAL_"] = float(predg["y_pred"].mean() / dfg["y"].iloc[-1])

    # par groupe
    for g, gdf in df.groupby(group_col):
        dfx = (gdf.groupby("launch_year")["price_per_piece"].mean()
                  .reset_index().rename(columns={"launch_year":"date","price_per_piece":"y"}))
        if len(dfx) < 6:   # pas assez d'années
            continue
        dfx["date"] = pd.to_datetime(dfx["date"], format="%Y")

        exp = TSForecastingExperiment()
        exp.setup(data=dfx, target="y", session_id=8, fh=fh, fold=1, numeric_imputation_target="linear")
        best = exp.compare_models(turbo=True)
        pred = exp.predict_model(best, fh=fh)
        factors[g] = float(pred["y_pred"].mean() / dfx["y"].iloc[-1])

    return factors

# calcule les facteurs 5 et 10 ans
time_factor_5 = build_time_factor_by_group(fh=5)
#time_factor_10 = build_time_factor_by_group(fh=10)
# Out:
# <style type="text/css">
# #T_22503_row28_col1, #T_22503_row31_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_22503">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22503_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_22503_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22503_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22503_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_22503_row0_col1" class="data row0 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_22503_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_22503_row1_col1" class="data row1 col1" >y</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_22503_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_22503_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_22503_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_22503_row3_col1" class="data row3 col1" >Present</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_22503_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_22503_row4_col1" class="data row4 col1" >(25, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_22503_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_22503_row5_col1" class="data row5 col1" >(25, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_22503_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_22503_row6_col1" class="data row6 col1" >(20, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_22503_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_22503_row7_col1" class="data row7 col1" >(5, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_22503_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_22503_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_22503_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_22503_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_22503_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_22503_row10_col1" class="data row10 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_22503_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_22503_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_22503_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_22503_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_22503_row13_col0" class="data row13 col0" >User Defined Seasonal Period(s)</td>
#       <td id="T_22503_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_22503_row14_col0" class="data row14 col0" >Ignore Seasonality Test</td>
#       <td id="T_22503_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_22503_row15_col0" class="data row15 col0" >Seasonality Detection Algo</td>
#       <td id="T_22503_row15_col1" class="data row15 col1" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_22503_row16_col0" class="data row16 col0" >Max Period to Consider</td>
#       <td id="T_22503_row16_col1" class="data row16 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_22503_row17_col0" class="data row17 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_22503_row17_col1" class="data row17 col1" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_22503_row18_col0" class="data row18 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_22503_row18_col1" class="data row18 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_22503_row19_col0" class="data row19 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_22503_row19_col1" class="data row19 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_22503_row20_col0" class="data row20 col0" >Remove Harmonics</td>
#       <td id="T_22503_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_22503_row21_col0" class="data row21 col0" >Harmonics Order Method</td>
#       <td id="T_22503_row21_col1" class="data row21 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_22503_row22_col0" class="data row22 col0" >Num Seasonalities to Use</td>
#       <td id="T_22503_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_22503_row23_col0" class="data row23 col0" >All Seasonalities to Use</td>
#       <td id="T_22503_row23_col1" class="data row23 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_22503_row24_col0" class="data row24 col0" >Primary Seasonality</td>
#       <td id="T_22503_row24_col1" class="data row24 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_22503_row25_col0" class="data row25 col0" >Seasonality Present</td>
#       <td id="T_22503_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_22503_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_22503_row26_col1" class="data row26 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_22503_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_22503_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_22503_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_22503_row28_col1" class="data row28 col1" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_22503_row29_col0" class="data row29 col0" >Recommended d</td>
#       <td id="T_22503_row29_col1" class="data row29 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_22503_level0_row30" class="row_heading level0 row30" >30</
# <style type="text/css">
# #T_6cf52 th {
#   text-align: left;
# }
# #T_6cf52_row0_col0 {
#   text-align: left;
# }
# #T_6cf52_row0_col1, #T_6cf52_row0_col2, #T_6cf52_row0_col3, #T_6cf52_row0_col4, #T_6cf52_row0_col5, #T_6cf52_row0_col6, #T_6cf52_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6cf52_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6cf52">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6cf52_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6cf52_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_6cf52_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_6cf52_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_6cf52_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_6cf52_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_6cf52_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_6cf52_level0_col7" class="col_heading level0 col7" >R2</th>
#       <th id="T_6cf52_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6cf52_level0_row0" class="row_heading level0 row0" >croston</th>
#       <td id="T_6cf52_row0_col0" class="data row0 col0" >Croston</td>
#       <td id="T_6cf52_row0_col1" class="data row0 col1" >1.0069</td>
#       <td id="T_6cf52_row0_col2" class="data row0 col2" >0.5719</td>
#       <td id="T_6cf52_row0_col3" class="data row0 col3" >2.1482</td>
#       <td id="T_6cf52_row0_col4" class="data row0 col4" >2.1483</td>
#       <td id="T_6cf52_row0_col5" class="data row0 col5" >12.3029</td>
#       <td id="T_6cf52_row0_col6" class="data row0 col6" >1.7069</td>
#       <td id="T_6cf52_row0_col7" class="data row0 col7" >-10530.1731</td>
#       <td id="T_6cf52_row0_col8" class="data row0 col8" >0.1000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_39ac2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39ac2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_39ac2_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_39ac2_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_39ac2_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_39ac2_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_39ac2_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_39ac2_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_39ac2_level0_col7" class="col_heading level0 col7" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39ac2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_39ac2_row0_col0" class="data row0 col0" >Croston</td>
#       <td id="T_39ac2_row0_col1" class="data row0 col1" >0.6669</td>
#       <td id="T_39ac2_row0_col2" class="data row0 col2" >0.3003</td>
#       <td id="T_39ac2_row0_col3" class="data row0 col3" >0.8225</td>
#       <td id="T_39ac2_row0_col4" class="data row0 col4" >0.8483</td>
#       <td id="T_39ac2_row0_col5" class="data row0 col5" >4.1411</td>
#       <td id="T_39ac2_row0_col6" class="data row0 col6" >1.2246</td>
#       <td id="T_39ac2_row0_col7" class="data row0 col7" >-15.7253</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_9b6a2_row31_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9b6a2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b6a2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9b6a2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b6a2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9b6a2_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_9b6a2_row0_col1" class="data row0 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9b6a2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9b6a2_row1_col1" class="data row1 col1" >y</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9b6a2_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_9b6a2_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9b6a2_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_9b6a2_row3_col1" class="data row3 col1" >Present</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9b6a2_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_9b6a2_row4_col1" class="data row4 col1" >(18, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9b6a2_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_9b6a2_row5_col1" class="data row5 col1" >(18, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9b6a2_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_9b6a2_row6_col1" class="data row6 col1" >(13, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9b6a2_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_9b6a2_row7_col1" class="data row7 col1" >(5, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9b6a2_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_9b6a2_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9b6a2_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_9b6a2_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9b6a2_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_9b6a2_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9b6a2_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_9b6a2_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9b6a2_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_9b6a2_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9b6a2_row13_col0" class="data row13 col0" >User Defined Seasonal Period(s)</td>
#       <td id="T_9b6a2_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9b6a2_row14_col0" class="data row14 col0" >Ignore Seasonality Test</td>
#       <td id="T_9b6a2_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9b6a2_row15_col0" class="data row15 col0" >Seasonality Detection Algo</td>
#       <td id="T_9b6a2_row15_col1" class="data row15 col1" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9b6a2_row16_col0" class="data row16 col0" >Max Period to Consider</td>
#       <td id="T_9b6a2_row16_col1" class="data row16 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9b6a2_row17_col0" class="data row17 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_9b6a2_row17_col1" class="data row17 col1" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9b6a2_row18_col0" class="data row18 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_9b6a2_row18_col1" class="data row18 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9b6a2_row19_col0" class="data row19 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_9b6a2_row19_col1" class="data row19 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_9b6a2_row20_col0" class="data row20 col0" >Remove Harmonics</td>
#       <td id="T_9b6a2_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_9b6a2_row21_col0" class="data row21 col0" >Harmonics Order Method</td>
#       <td id="T_9b6a2_row21_col1" class="data row21 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_9b6a2_row22_col0" class="data row22 col0" >Num Seasonalities to Use</td>
#       <td id="T_9b6a2_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_9b6a2_row23_col0" class="data row23 col0" >All Seasonalities to Use</td>
#       <td id="T_9b6a2_row23_col1" class="data row23 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_9b6a2_row24_col0" class="data row24 col0" >Primary Seasonality</td>
#       <td id="T_9b6a2_row24_col1" class="data row24 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_9b6a2_row25_col0" class="data row25 col0" >Seasonality Present</td>
#       <td id="T_9b6a2_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_9b6a2_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_9b6a2_row26_col1" class="data row26 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_9b6a2_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_9b6a2_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_9b6a2_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_9b6a2_row28_col1" class="data row28 col1" >Maybe</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_9b6a2_row29_col0" class="data row29 col0" >Recommended d</td>
#       <td id="T_9b6a2_row29_col1" class="data row29 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9b6a2_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T
# <style type="text/css">
# #T_791d2 th {
#   text-align: left;
# }
# #T_791d2_row0_col0 {
#   text-align: left;
# }
# #T_791d2_row0_col1, #T_791d2_row0_col2, #T_791d2_row0_col3, #T_791d2_row0_col4, #T_791d2_row0_col5, #T_791d2_row0_col6, #T_791d2_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_791d2_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_791d2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_791d2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_791d2_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_791d2_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_791d2_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_791d2_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_791d2_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_791d2_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_791d2_level0_col7" class="col_heading level0 col7" >R2</th>
#       <th id="T_791d2_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_791d2_level0_row0" class="row_heading level0 row0" >croston</th>
#       <td id="T_791d2_row0_col0" class="data row0 col0" >Croston</td>
#       <td id="T_791d2_row0_col1" class="data row0 col1" >2.4794</td>
#       <td id="T_791d2_row0_col2" class="data row0 col2" >1.7430</td>
#       <td id="T_791d2_row0_col3" class="data row0 col3" >0.1101</td>
#       <td id="T_791d2_row0_col4" class="data row0 col4" >0.1106</td>
#       <td id="T_791d2_row0_col5" class="data row0 col5" >1.2713</td>
#       <td id="T_791d2_row0_col6" class="data row0 col6" >0.7694</td>
#       <td id="T_791d2_row0_col7" class="data row0 col7" >-116.6300</td>
#       <td id="T_791d2_row0_col8" class="data row0 col8" >0.0900</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_7767e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7767e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7767e_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_7767e_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_7767e_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_7767e_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_7767e_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_7767e_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_7767e_level0_col7" class="col_heading level0 col7" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7767e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7767e_row0_col0" class="data row0 col0" >Croston</td>
#       <td id="T_7767e_row0_col1" class="data row0 col1" >2.1580</td>
#       <td id="T_7767e_row0_col2" class="data row0 col2" >1.3812</td>
#       <td id="T_7767e_row0_col3" class="data row0 col3" >0.0677</td>
#       <td id="T_7767e_row0_col4" class="data row0 col4" >0.0681</td>
#       <td id="T_7767e_row0_col5" class="data row0 col5" >0.8034</td>
#       <td id="T_7767e_row0_col6" class="data row0 col6" >0.5688</td>
#       <td id="T_7767e_row0_col7" class="data row0 col7" >-80.6699</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c1e1d_row28_col1, #T_c1e1d_row31_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c1e1d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1e1d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c1e1d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1e1d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c1e1d_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_c1e1d_row0_col1" class="data row0 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c1e1d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c1e1d_row1_col1" class="data row1 col1" >y</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c1e1d_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_c1e1d_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c1e1d_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_c1e1d_row3_col1" class="data row3 col1" >Present</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c1e1d_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_c1e1d_row4_col1" class="data row4 col1" >(21, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c1e1d_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_c1e1d_row5_col1" class="data row5 col1" >(21, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c1e1d_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_c1e1d_row6_col1" class="data row6 col1" >(16, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c1e1d_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_c1e1d_row7_col1" class="data row7 col1" >(5, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c1e1d_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_c1e1d_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c1e1d_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_c1e1d_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c1e1d_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_c1e1d_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c1e1d_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_c1e1d_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c1e1d_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_c1e1d_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c1e1d_row13_col0" class="data row13 col0" >User Defined Seasonal Period(s)</td>
#       <td id="T_c1e1d_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c1e1d_row14_col0" class="data row14 col0" >Ignore Seasonality Test</td>
#       <td id="T_c1e1d_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c1e1d_row15_col0" class="data row15 col0" >Seasonality Detection Algo</td>
#       <td id="T_c1e1d_row15_col1" class="data row15 col1" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c1e1d_row16_col0" class="data row16 col0" >Max Period to Consider</td>
#       <td id="T_c1e1d_row16_col1" class="data row16 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c1e1d_row17_col0" class="data row17 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_c1e1d_row17_col1" class="data row17 col1" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c1e1d_row18_col0" class="data row18 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_c1e1d_row18_col1" class="data row18 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_c1e1d_row19_col0" class="data row19 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_c1e1d_row19_col1" class="data row19 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_c1e1d_row20_col0" class="data row20 col0" >Remove Harmonics</td>
#       <td id="T_c1e1d_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_c1e1d_row21_col0" class="data row21 col0" >Harmonics Order Method</td>
#       <td id="T_c1e1d_row21_col1" class="data row21 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_c1e1d_row22_col0" class="data row22 col0" >Num Seasonalities to Use</td>
#       <td id="T_c1e1d_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_c1e1d_row23_col0" class="data row23 col0" >All Seasonalities to Use</td>
#       <td id="T_c1e1d_row23_col1" class="data row23 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_c1e1d_row24_col0" class="data row24 col0" >Primary Seasonality</td>
#       <td id="T_c1e1d_row24_col1" class="data row24 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_c1e1d_row25_col0" class="data row25 col0" >Seasonality Present</td>
#       <td id="T_c1e1d_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_c1e1d_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_c1e1d_row26_col1" class="data row26 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_c1e1d_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_c1e1d_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_c1e1d_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_c1e1d_row28_col1" class="data row28 col1" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_c1e1d_row29_col0" class="data row29 col0" >Recommended d</td>
#       <td id="T_c1e1d_row29_col1" class="data row29 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c1e1d_level0_row30" class="row_heading level0 row30" >30</
# <style type="text/css">
# #T_7bd05 th {
#   text-align: left;
# }
# #T_7bd05_row0_col0 {
#   text-align: left;
# }
# #T_7bd05_row0_col1, #T_7bd05_row0_col2, #T_7bd05_row0_col3, #T_7bd05_row0_col4, #T_7bd05_row0_col5, #T_7bd05_row0_col6, #T_7bd05_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_7bd05_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_7bd05">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7bd05_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7bd05_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_7bd05_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_7bd05_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_7bd05_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_7bd05_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_7bd05_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_7bd05_level0_col7" class="col_heading level0 col7" >R2</th>
#       <th id="T_7bd05_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7bd05_level0_row0" class="row_heading level0 row0" >croston</th>
#       <td id="T_7bd05_row0_col0" class="data row0 col0" >Croston</td>
#       <td id="T_7bd05_row0_col1" class="data row0 col1" >0.2501</td>
#       <td id="T_7bd05_row0_col2" class="data row0 col2" >0.1233</td>
#       <td id="T_7bd05_row0_col3" class="data row0 col3" >0.0916</td>
#       <td id="T_7bd05_row0_col4" class="data row0 col4" >0.0920</td>
#       <td id="T_7bd05_row0_col5" class="data row0 col5" >0.7343</td>
#       <td id="T_7bd05_row0_col6" class="data row0 col6" >0.5335</td>
#       <td id="T_7bd05_row0_col7" class="data row0 col7" >-96.8201</td>
#       <td id="T_7bd05_row0_col8" class="data row0 col8" >0.0800</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_68bba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68bba_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_68bba_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_68bba_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_68bba_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_68bba_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_68bba_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_68bba_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_68bba_level0_col7" class="col_heading level0 col7" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68bba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_68bba_row0_col0" class="data row0 col0" >Croston</td>
#       <td id="T_68bba_row0_col1" class="data row0 col1" >11.6607</td>
#       <td id="T_68bba_row0_col2" class="data row0 col2" >8.9823</td>
#       <td id="T_68bba_row0_col3" class="data row0 col3" >2.9007</td>
#       <td id="T_68bba_row0_col4" class="data row0 col4" >5.4755</td>
#       <td id="T_68bba_row0_col5" class="data row0 col5" >0.7983</td>
#       <td id="T_68bba_row0_col6" class="data row0 col6" >1.1408</td>
#       <td id="T_68bba_row0_col7" class="data row0 col7" >-0.3685</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a401e_row28_col1, #T_a401e_row31_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a401e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a401e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a401e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a401e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a401e_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_a401e_row0_col1" class="data row0 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a401e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a401e_row1_col1" class="data row1 col1" >y</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a401e_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_a401e_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a401e_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_a401e_row3_col1" class="data row3 col1" >Present</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a401e_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_a401e_row4_col1" class="data row4 col1" >(25, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a401e_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_a401e_row5_col1" class="data row5 col1" >(25, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a401e_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_a401e_row6_col1" class="data row6 col1" >(20, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a401e_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_a401e_row7_col1" class="data row7 col1" >(5, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a401e_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_a401e_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a401e_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_a401e_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a401e_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_a401e_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a401e_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_a401e_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a401e_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_a401e_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a401e_row13_col0" class="data row13 col0" >User Defined Seasonal Period(s)</td>
#       <td id="T_a401e_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a401e_row14_col0" class="data row14 col0" >Ignore Seasonality Test</td>
#       <td id="T_a401e_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a401e_row15_col0" class="data row15 col0" >Seasonality Detection Algo</td>
#       <td id="T_a401e_row15_col1" class="data row15 col1" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a401e_row16_col0" class="data row16 col0" >Max Period to Consider</td>
#       <td id="T_a401e_row16_col1" class="data row16 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a401e_row17_col0" class="data row17 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_a401e_row17_col1" class="data row17 col1" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a401e_row18_col0" class="data row18 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_a401e_row18_col1" class="data row18 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a401e_row19_col0" class="data row19 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_a401e_row19_col1" class="data row19 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a401e_row20_col0" class="data row20 col0" >Remove Harmonics</td>
#       <td id="T_a401e_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a401e_row21_col0" class="data row21 col0" >Harmonics Order Method</td>
#       <td id="T_a401e_row21_col1" class="data row21 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_a401e_row22_col0" class="data row22 col0" >Num Seasonalities to Use</td>
#       <td id="T_a401e_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_a401e_row23_col0" class="data row23 col0" >All Seasonalities to Use</td>
#       <td id="T_a401e_row23_col1" class="data row23 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_a401e_row24_col0" class="data row24 col0" >Primary Seasonality</td>
#       <td id="T_a401e_row24_col1" class="data row24 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_a401e_row25_col0" class="data row25 col0" >Seasonality Present</td>
#       <td id="T_a401e_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_a401e_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_a401e_row26_col1" class="data row26 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_a401e_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_a401e_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_a401e_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_a401e_row28_col1" class="data row28 col1" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_a401e_row29_col0" class="data row29 col0" >Recommended d</td>
#       <td id="T_a401e_row29_col1" class="data row29 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a401e_level0_row30" class="row_heading level0 row30" >30</
# <style type="text/css">
# #T_7c75c th {
#   text-align: left;
# }
# #T_7c75c_row0_col0 {
#   text-align: left;
# }
# #T_7c75c_row0_col1, #T_7c75c_row0_col2, #T_7c75c_row0_col3, #T_7c75c_row0_col4, #T_7c75c_row0_col5, #T_7c75c_row0_col6, #T_7c75c_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_7c75c_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_7c75c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c75c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7c75c_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_7c75c_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_7c75c_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_7c75c_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_7c75c_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_7c75c_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_7c75c_level0_col7" class="col_heading level0 col7" >R2</th>
#       <th id="T_7c75c_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c75c_level0_row0" class="row_heading level0 row0" >croston</th>
#       <td id="T_7c75c_row0_col0" class="data row0 col0" >Croston</td>
#       <td id="T_7c75c_row0_col1" class="data row0 col1" >0.7782</td>
#       <td id="T_7c75c_row0_col2" class="data row0 col2" >0.4081</td>
#       <td id="T_7c75c_row0_col3" class="data row0 col3" >1.7346</td>
#       <td id="T_7c75c_row0_col4" class="data row0 col4" >1.7348</td>
#       <td id="T_7c75c_row0_col5" class="data row0 col5" >13.8978</td>
#       <td id="T_7c75c_row0_col6" class="data row0 col6" >1.7403</td>
#       <td id="T_7c75c_row0_col7" class="data row0 col7" >-3936.6761</td>
#       <td id="T_7c75c_row0_col8" class="data row0 col8" >0.0900</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ffd9f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ffd9f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ffd9f_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_ffd9f_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_ffd9f_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_ffd9f_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_ffd9f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_ffd9f_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_ffd9f_level0_col7" class="col_heading level0 col7" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ffd9f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ffd9f_row0_col0" class="data row0 col0" >Croston</td>
#       <td id="T_ffd9f_row0_col1" class="data row0 col1" >0.6213</td>
#       <td id="T_ffd9f_row0_col2" class="data row0 col2" >0.2810</td>
#       <td id="T_ffd9f_row0_col3" class="data row0 col3" >1.0250</td>
#       <td id="T_ffd9f_row0_col4" class="data row0 col4" >1.0254</td>
#       <td id="T_ffd9f_row0_col5" class="data row0 col5" >8.3360</td>
#       <td id="T_ffd9f_row0_col6" class="data row0 col6" >1.5986</td>
#       <td id="T_ffd9f_row0_col7" class="data row0 col7" >-1398.7488</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7df6d_row25_col1, #T_7df6d_row31_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7df6d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7df6d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7df6d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7df6d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7df6d_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_7df6d_row0_col1" class="data row0 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_7df6d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7df6d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7df6d_row1_col1" class="data row1 col1" >y</td>
#     </tr>
#     <tr>
#       <th id="T_7df6d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7df6d_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_7df6d_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_7df6d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7df6d_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_7df6d_row3_col1" class="data row3 col1" >Present</td>
#     </tr>
#     <tr>
#       <th id="T_7df6d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7df6d_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_7df6d_row4_col1" class="data row4 col1" >(18, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_7df6d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7df6d_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_7df6d_row5_col1" class="data row5 col1" >(18, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_7df6d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7df6d_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_7df6d_row6_col1" class="data row6 col1" >(13, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_7df6d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7df6d_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_7df6d_row7_col1" class="data row7 col1" >(5, 2)</td>
#     </tr>
#     <tr>
# ...
#       <td id="T_da47d_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_da47d_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_da47d_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_da47d_row26_col1" class="data row26 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_da47d_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_da47d_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_da47d_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_da47d_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_da47d_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_da47d_row28_col1" class="data row28 col1" >No</td>
#     </tr>
#     <tr>
#       <th id="T_da47d_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_da47d_row29_col0" class="data row29 col0" >Recommended d</td>
#       <td id="T_da47d_row29_col1" class="data row29 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_da47d_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_da
# <style type="text/css">
# #T_4bf2f th {
#   text-align: left;
# }
# #T_4bf2f_row0_col0 {
#   text-align: left;
# }
# #T_4bf2f_row0_col1, #T_4bf2f_row0_col2, #T_4bf2f_row0_col3, #T_4bf2f_row0_col4, #T_4bf2f_row0_col5, #T_4bf2f_row0_col6, #T_4bf2f_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_4bf2f_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_4bf2f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4bf2f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4bf2f_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_4bf2f_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_4bf2f_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_4bf2f_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_4bf2f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_4bf2f_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_4bf2f_level0_col7" class="col_heading level0 col7" >R2</th>
#       <th id="T_4bf2f_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4bf2f_level0_row0" class="row_heading level0 row0" >croston</th>
#       <td id="T_4bf2f_row0_col0" class="data row0 col0" >Croston</td>
#       <td id="T_4bf2f_row0_col1" class="data row0 col1" >2.3810</td>
#       <td id="T_4bf2f_row0_col2" class="data row0 col2" >1.5502</td>
#       <td id="T_4bf2f_row0_col3" class="data row0 col3" >0.4360</td>
#       <td id="T_4bf2f_row0_col4" class="data row0 col4" >0.4453</td>
#       <td id="T_4bf2f_row0_col5" class="data row0 col5" >5.2389</td>
#       <td id="T_4bf2f_row0_col6" class="data row0 col6" >1.3220</td>
#       <td id="T_4bf2f_row0_col7" class="data row0 col7" >-23.2096</td>
#       <td id="T_4bf2f_row0_col8" class="data row0 col8" >0.0900</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_6f86b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f86b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6f86b_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_6f86b_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_6f86b_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_6f86b_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_6f86b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_6f86b_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_6f86b_level0_col7" class="col_heading level0 col7" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f86b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6f86b_row0_col0" class="data row0 col0" >Croston</td>
#       <td id="T_6f86b_row0_col1" class="data row0 col1" >1.7178</td>
#       <td id="T_6f86b_row0_col2" class="data row0 col2" >1.0905</td>
#       <td id="T_6f86b_row0_col3" class="data row0 col3" >0.2560</td>
#       <td id="T_6f86b_row0_col4" class="data row0 col4" >0.2603</td>
#       <td id="T_6f86b_row0_col5" class="data row0 col5" >2.4612</td>
#       <td id="T_6f86b_row0_col6" class="data row0 col6" >1.0305</td>
#       <td id="T_6f86b_row0_col7" class="data row0 col7" >-29.3565</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_9f5e4_row28_col1, #T_9f5e4_row31_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9f5e4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f5e4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9f5e4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f5e4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9f5e4_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_9f5e4_row0_col1" class="data row0 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9f5e4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9f5e4_row1_col1" class="data row1 col1" >y</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9f5e4_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_9f5e4_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9f5e4_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_9f5e4_row3_col1" class="data row3 col1" >Present</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9f5e4_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_9f5e4_row4_col1" class="data row4 col1" >(11, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9f5e4_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_9f5e4_row5_col1" class="data row5 col1" >(11, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9f5e4_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_9f5e4_row6_col1" class="data row6 col1" >(6, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9f5e4_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_9f5e4_row7_col1" class="data row7 col1" >(5, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9f5e4_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_9f5e4_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9f5e4_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_9f5e4_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9f5e4_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_9f5e4_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9f5e4_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_9f5e4_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9f5e4_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_9f5e4_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9f5e4_row13_col0" class="data row13 col0" >User Defined Seasonal Period(s)</td>
#       <td id="T_9f5e4_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9f5e4_row14_col0" class="data row14 col0" >Ignore Seasonality Test</td>
#       <td id="T_9f5e4_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9f5e4_row15_col0" class="data row15 col0" >Seasonality Detection Algo</td>
#       <td id="T_9f5e4_row15_col1" class="data row15 col1" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9f5e4_row16_col0" class="data row16 col0" >Max Period to Consider</td>
#       <td id="T_9f5e4_row16_col1" class="data row16 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9f5e4_row17_col0" class="data row17 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_9f5e4_row17_col1" class="data row17 col1" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9f5e4_row18_col0" class="data row18 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_9f5e4_row18_col1" class="data row18 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9f5e4_row19_col0" class="data row19 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_9f5e4_row19_col1" class="data row19 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_9f5e4_row20_col0" class="data row20 col0" >Remove Harmonics</td>
#       <td id="T_9f5e4_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_9f5e4_row21_col0" class="data row21 col0" >Harmonics Order Method</td>
#       <td id="T_9f5e4_row21_col1" class="data row21 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_9f5e4_row22_col0" class="data row22 col0" >Num Seasonalities to Use</td>
#       <td id="T_9f5e4_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_9f5e4_row23_col0" class="data row23 col0" >All Seasonalities to Use</td>
#       <td id="T_9f5e4_row23_col1" class="data row23 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_9f5e4_row24_col0" class="data row24 col0" >Primary Seasonality</td>
#       <td id="T_9f5e4_row24_col1" class="data row24 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_9f5e4_row25_col0" class="data row25 col0" >Seasonality Present</td>
#       <td id="T_9f5e4_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_9f5e4_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_9f5e4_row26_col1" class="data row26 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_9f5e4_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_9f5e4_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_9f5e4_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_9f5e4_row28_col1" class="data row28 col1" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_9f5e4_row29_col0" class="data row29 col0" >Recommended d</td>
#       <td id="T_9f5e4_row29_col1" class="data row29 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9f5e4_level0_row30" class="row_heading level0 row30" >30</t
# <style type="text/css">
# #T_dc6f1 th {
#   text-align: left;
# }
# #T_dc6f1_row0_col0, #T_dc6f1_row0_col1, #T_dc6f1_row0_col2 {
#   text-align: left;
# }
# #T_dc6f1_row0_col3, #T_dc6f1_row0_col4, #T_dc6f1_row0_col5, #T_dc6f1_row0_col6, #T_dc6f1_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_dc6f1_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_dc6f1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc6f1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_dc6f1_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_dc6f1_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_dc6f1_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_dc6f1_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_dc6f1_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_dc6f1_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_dc6f1_level0_col7" class="col_heading level0 col7" >R2</th>
#       <th id="T_dc6f1_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc6f1_level0_row0" class="row_heading level0 row0" >croston</th>
#       <td id="T_dc6f1_row0_col0" class="data row0 col0" >Croston</td>
#       <td id="T_dc6f1_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_dc6f1_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_dc6f1_row0_col3" class="data row0 col3" >0.0144</td>
#       <td id="T_dc6f1_row0_col4" class="data row0 col4" >0.0161</td>
#       <td id="T_dc6f1_row0_col5" class="data row0 col5" >0.1861</td>
#       <td id="T_dc6f1_row0_col6" class="data row0 col6" >0.1659</td>
#       <td id="T_dc6f1_row0_col7" class="data row0 col7" >-4.1473</td>
#       <td id="T_dc6f1_row0_col8" class="data row0 col8" >0.1000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_f1b9c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1b9c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f1b9c_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_f1b9c_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_f1b9c_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_f1b9c_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_f1b9c_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_f1b9c_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_f1b9c_level0_col7" class="col_heading level0 col7" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1b9c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f1b9c_row0_col0" class="data row0 col0" >Croston</td>
#       <td id="T_f1b9c_row0_col1" class="data row0 col1" >1.4186</td>
#       <td id="T_f1b9c_row0_col2" class="data row0 col2" >1.4972</td>
#       <td id="T_f1b9c_row0_col3" class="data row0 col3" >0.0108</td>
#       <td id="T_f1b9c_row0_col4" class="data row0 col4" >0.0128</td>
#       <td id="T_f1b9c_row0_col5" class="data row0 col5" >0.1438</td>
#       <td id="T_f1b9c_row0_col6" class="data row0 col6" >0.1308</td>
#       <td id="T_f1b9c_row0_col7" class="data row0 col7" >-0.6483</td>
#     </tr>
#   </tbody>
# </table>

# %%
def predict_future_price(pieces, minifigs, theme_group, years_ahead=10, launch_year=2025):
    # choisir le bon modèle
    mdl = models_by_group.get(theme_group, global_model)
    low, high = ppp_bounds_by_group.get(theme_group, global_bounds)

    # features d'entrée
    size_cat = pd.cut(
        [pieces],
        bins=[0, 500, 1000, 2000, 3000, df["pieces"].max()],
        labels=["<500", "500-1000", "1000-2000", "2000-3000", "3000+"],
        include_lowest=True
    )[0]

    x = pd.DataFrame([{
        "pieces": pieces,
        "minifigs": minifigs,
        "launch_year": launch_year,
        "size_category": size_cat,
        # IMPORTANT : si ton modèle global a vu theme_group, on l'inclut aussi
        "theme_group": theme_group
    }])
    
    x["retail_price"] = np.nan

    # prédire le prix/pp
    ppp = predict_model(mdl, data=x)["prediction_label"].iloc[0]
    ppp = float(np.clip(ppp, low, high))  # coupe les valeurs farfelues

    price_today = ppp * pieces

    # facteur temporel
    if years_ahead <= 0:
        return round(price_today, 2)

    factors_map = {5: time_factor_5,}
    tf = factors_map.get(years_ahead)  # fallback 10 ans
    factor = tf.get(theme_group, tf.get("_GLOBAL_", 1.0))

    return round(price_today * factor, 2)

# %%
print("Licensed, 421 pcs, 0 figs → 5 ans :",
      predict_future_price(421, 0, "Licensed", years_ahead=5), "€")
# Out:
# Licensed, 421 pcs, 0 figs → 5 ans : 25.89 €
